# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cardioActivities.csv')
df
# Out:
#                     Date                           Activity Id     Type  \
# 0    2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1    2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2    2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3    2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4    2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ..                   ...                                   ...      ...
# 503  2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 504  2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 505  2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 506  2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 507  2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#     Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# ...

# %%
df
# Out:
#                     Date                           Activity Id     Type  \
# 0    2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1    2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2    2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3    2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4    2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ..                   ...                                   ...      ...
# 503  2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 504  2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 505  2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 506  2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 507  2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#     Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# ...

# %%
df.Notes
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 503    NaN
# 504    NaN
# 505    NaN
# 506    NaN
# 507    NaN
# Name: Notes, Length: 508, dtype: object

# %%
df.drop(columns = ['Friend\'s Tagged','Route Name','GPX File','Activity Id','Calories Burned', 'Notes'],inplace = True)

# %%
df
# Out:
#                     Date     Type  Distance (km) Duration Average Pace  \
# 0    2018-11-11 14:05:12  Running          10.44    58:40         5:37
# 1    2018-11-09 15:02:35  Running          12.84  1:14:12         5:47
# 2    2018-11-04 16:05:00  Running          13.01  1:15:16         5:47
# 3    2018-11-01 14:03:58  Running          12.98  1:14:25         5:44
# 4    2018-10-27 17:01:36  Running          13.02  1:12:50         5:36
# ..                   ...      ...            ...      ...          ...
# 503  2012-08-28 07:06:57  Walking           1.57    13:39         8:41
# 504  2012-08-24 12:59:42  Walking           1.48    17:56        12:09
# 505  2012-08-24 10:12:16  Walking           1.49    13:43         9:14
# 506  2012-08-24 08:13:12  Running           3.15    16:00         5:05
# 507  2012-08-22 18:53:54  Running           5.69    31:08         5:29
#
#      Average Speed (km/h)  Climb (m)  Average Heart Rate (bpm)
# ...

# %%
# Out:
# Type
# Running    459
# Cycling     29
# Walking     18
# Other        2
# Name: count, dtype: int64

# %%
df['Type'] = df['Type'].replace('Other', 'Unicycling')

# %%
activity_types = df['Type'].value_counts()
activity_types
# Out:
# Type
# Running       459
# Cycling        29
# Walking        18
# Unicycling      2
# Name: count, dtype: int64

# %%
missing_values = df.isna().sum()

# %%
missing_values
# Out:
# Date                          0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# dtype: int64

# %%
avg_hr_run = df[df['Type'] == 'Running']['Average Heart Rate (bpm)'].mean()
avg_hr_cycle = df[df['Type'] == 'Cycling']['Average Heart Rate (bpm)'].mean()
avg_hr_walk = df[df['Type'] == 'Walking']['Average Heart Rate (bpm)'].mean()
avg_hr_unicycle = df[df['Type'] == 'Unicycling']['Average Heart Rate (bpm)'].mean()

# %%
avg_hr_walk
# Out:
# nan

# %%
df_run = df[df['Type'] == 'Running'].copy()
df_walk = df[df['Type'] == 'Walking'].copy()
df_cycle = df[df['Type'] == 'Cycling'].copy()
df_unicycle = df[df['Type'] == 'Unicycling'].copy()
# Out:
#                     Date     Type  Distance (km) Duration Average Pace  \
# 0    2018-11-11 14:05:12  Running          10.44    58:40         5:37
# 1    2018-11-09 15:02:35  Running          12.84  1:14:12         5:47
# 2    2018-11-04 16:05:00  Running          13.01  1:15:16         5:47
# 3    2018-11-01 14:03:58  Running          12.98  1:14:25         5:44
# 4    2018-10-27 17:01:36  Running          13.02  1:12:50         5:36
# ..                   ...      ...            ...      ...          ...
# 503  2012-08-28 07:06:57  Walking           1.57    13:39         8:41
# 504  2012-08-24 12:59:42  Walking           1.48    17:56        12:09
# 505  2012-08-24 10:12:16  Walking           1.49    13:43         9:14
# 506  2012-08-24 08:13:12  Running           3.15    16:00         5:05
# 507  2012-08-22 18:53:54  Running           5.69    31:08         5:29
#
#      Average Speed (km/h)  Climb (m)  Average Heart Rate (bpm)
# ...

# %%
df_walk['Average Heart Rate (bpm)'].fillna(110, inplace=True)
df_run['Average Heart Rate (bpm)'].fillna(int(avg_hr_run), inplace=True)
df_cycle['Average Heart Rate (bpm)'].fillna(int(avg_hr_cycle), inplace=True)
df_unicycle['Average Heart Rate (bpm)'].fillna(int(avg_hr_unicycle), inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_40264\2200065944.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_walk['Average Heart Rate (bpm)'].fillna(110, inplace=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_40264\2200065944.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
missing_values = df.isna().sum()
missing_values
# Out:
# Date                          0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# dtype: int64

# %%
# Out:
#                     Date     Type  Distance (km) Duration Average Pace  \
# 0    2018-11-11 14:05:12  Running          10.44    58:40         5:37
# 1    2018-11-09 15:02:35  Running          12.84  1:14:12         5:47
# 2    2018-11-04 16:05:00  Running          13.01  1:15:16         5:47
# 3    2018-11-01 14:03:58  Running          12.98  1:14:25         5:44
# 4    2018-10-27 17:01:36  Running          13.02  1:12:50         5:36
# ..                   ...      ...            ...      ...          ...
# 503  2012-08-28 07:06:57  Walking           1.57    13:39         8:41
# 504  2012-08-24 12:59:42  Walking           1.48    17:56        12:09
# 505  2012-08-24 10:12:16  Walking           1.49    13:43         9:14
# 506  2012-08-24 08:13:12  Running           3.15    16:00         5:05
# 507  2012-08-22 18:53:54  Running           5.69    31:08         5:29
#
#      Average Speed (km/h)  Climb (m)  Average Heart Rate (bpm)
# ...

# %%
plt.style.use('ggplot')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
runs_subset_2013_2018 = df[(df['Date'] >= '2013-01-01') & (df['Date'] <= '2018-12-31')]
runs_subset_2013_2018
# Out:
#                    Date     Type  Distance (km) Duration Average Pace  \
# 0   2018-11-11 14:05:12  Running          10.44    58:40         5:37
# 1   2018-11-09 15:02:35  Running          12.84  1:14:12         5:47
# 2   2018-11-04 16:05:00  Running          13.01  1:15:16         5:47
# 3   2018-11-01 14:03:58  Running          12.98  1:14:25         5:44
# 4   2018-10-27 17:01:36  Running          13.02  1:12:50         5:36
# ..                  ...      ...            ...      ...          ...
# 472 2013-01-23 18:38:29  Running           8.65    50:13         5:48
# 473 2013-01-19 09:58:50  Running           3.39    15:56         4:42
# 474 2013-01-15 18:40:08  Running           6.72    32:42         4:52
# 475 2013-01-12 08:39:55  Running           3.09    20:07         6:31
# 476 2013-01-02 18:35:11  Running           5.47    31:24         5:45
#
#      Average Speed (km/h)  Climb (m)  Average Heart Rate (bpm)
# 0                   10.68        130                     159.0
# ...

# %%
runs_subset_2013_2018.plot(sharex=False,
                           figsize=(8,12),
                           linestyle='none',
                           marker='o',
                           markersize=3)
# Out:
# <Axes: >

# %%
runs_subset_2015_2018 = df[(df['Date'] >= '2015-01-01') & (df['Date'] <= '2018-12-31')]
runs_subset_2015_2018
# Out:
#                    Date     Type  Distance (km) Duration Average Pace  \
# 0   2018-11-11 14:05:12  Running          10.44    58:40         5:37
# 1   2018-11-09 15:02:35  Running          12.84  1:14:12         5:47
# 2   2018-11-04 16:05:00  Running          13.01  1:15:16         5:47
# 3   2018-11-01 14:03:58  Running          12.98  1:14:25         5:44
# 4   2018-10-27 17:01:36  Running          13.02  1:12:50         5:36
# ..                  ...      ...            ...      ...          ...
# 325 2015-01-28 18:43:29  Running          10.02    55:13         5:31
# 326 2015-01-26 18:30:18  Running          13.11  1:14:30         5:41
# 327 2015-01-14 17:50:00  Running           9.78    52:45         5:24
# 328 2015-01-12 18:20:00  Running           9.78    51:45         5:18
# 329 2015-01-03 17:20:00  Running           9.78    52:45         5:24
#
#      Average Speed (km/h)  Climb (m)  Average Heart Rate (bpm)
# 0                   10.68        130                     159.0
# ...

# %%
average_distance = runs_subset_2015_2018['Distance (km)'].mean()
average_distance
# Out:
# np.float64(13.742272727272727)

# %%
runs_distance = runs_subset_2015_2018[
    (runs_subset_2015_2018['Distance (km)'] >= 9.78) & 
    (runs_subset_2015_2018['Distance (km)'] <= 10.44)
]

# %%
runs_subset_2015_2018.set_index('Date', inplace=True)
weekly_averages = runs_subset_2015_2018.resample('W').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
runs_subset_2015_2018 = df[(df['Date'] >= '2015-01-01') & (df['Date'] <= '2018-12-31')]

# %%
fig, ax1,ax2 = plt.subplots()  # Create a figure and an Axes object
runs_subset_2015_2018.plot(ax=ax1)  # Plot your data on the created Axes
runs_subset_2015_2018.plot()
ax1.set(ylabel='Distance (km)', title='Historical data with averages')
ax1.axhline(runs_distance.mean(), color='blue', linewidth=1, linestyle='-.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 fig, ax1,ax2 = plt.subplots()  # Create a figure and an Axes object
#       2 runs_subset_2015_2018.plot(ax=ax1)  # Plot your data on the created Axes
#       3 runs_subset_2015_2018.plot()
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
fig, ax1 = plt.subplots()  # Create a figure and an Axes object
runs_subset_2015_2018.plot(ax=ax1)  # Plot your data on the created Axes

# Customize the plot
ax1.set(ylabel='Distance (km)', title='Historical data with averages')
ax1.axhline(runs_distance.mean(), color='blue', linewidth=1, linestyle='-.')  # Add a horizontal line for the mean

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 6
#       4 # Customize the plot
#       5 ax1.set(ylabel='Distance (km)', title='Historical data with averages')
# ----> 6 ax1.axhline(runs_distance.mean(), color='blue', linewidth=1, linestyle='-.')  # Add a horizontal line for the mean
#       8 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# ...

# %%
df_run_dist_annual = df[(df['Date'] >= '2013-01-01') & (df['Date'] <= '2018-12-31')]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax = df_run_dist_annual.plot(marker='*', markersize=14, linewidth=0, color='blue')
ax.set(ylim=[0, 1210], 
       xlim=['2012','2019'],
       ylabel='Distance (km)',
       xlabel='Years',
       title='Annual totals for distance')

ax.axhspan(1000, 1210, color='green', alpha=0.4)
ax.axhspan(800, 1000, color='yellow', alpha=0.3)

# %%
# !pip install statsmodel
# Out:
# ERROR: Could not find a version that satisfies the requirement statsmodel (from versions: none)
# ERROR: No matching distribution found for statsmodel
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df_run_hr_all = [102, 130, 145, 160, 125, 175, 138, 143, 110, 120, 155, 165, 132, 140, 105]

# Heart rate zones and corresponding zone names and colors
hr_zones = [100, 125, 133, 142, 151, 173]
zone_names = ['Easy', 'Moderate', 'Hard', 'Very hard', 'Maximal']
zone_colors = ['green', 'yellow', 'orange', 'tomato', 'red']

# Create plot
fig, ax = plt.subplots()

# Plot histogram
n, bins, patches = ax.hist(df_run_hr_all, bins=hr_zones, alpha=0.5, edgecolor='black')

# Customize patches with zone colors
for i in range(len(patches)):
    patches[i].set_facecolor(zone_colors[i])

# Customize plot
ax.set(title='Distribution of Heart Rate by Training Intensity', 
       ylabel='Number of Activities',
       xlabel='Heart Rate (bpm)')
ax.xaxis.set(ticks=hr_zones)

plt.show()

# %%
df_run_walk_cycle = pd.concat([df_run, df_walk, df_cycle])

# Columns for distance, climb, and speed
dist_climb_cols = ['Distance (km)', 'Climb (m)']
speed_col = ['Average Speed (km/h)']

# Calculating total distance and climb for each type of activity
df_totals = df_run_walk_cycle.groupby('Type')[dist_climb_cols].sum()

print('Totals for different training types:')
display(df_totals)

# Calculating summary statistics for each type of activity
df_summary = df_run_walk_cycle.groupby('Type')[dist_climb_cols + speed_col].describe()

# Combine totals with summary statistics
for col in dist_climb_cols:
    df_summary[(col, 'total')] = df_totals[col]

print('Summary statistics for different training types:')
display(df_summary)
# Out:
# Totals for different training types:
#          Distance (km)  Climb (m)
# Type
# Cycling         680.58       6976
# Running        5224.50      57278
# Walking          33.45        349
# Summary statistics for different training types:
#         Distance (km)                                                       \
#                 count       mean       std    min     25%     50%      75%
# Type
# Cycling          29.0  23.468276  9.451040  11.41  15.530  20.300  29.4000
# Running         459.0  11.382353  4.937853   0.76   7.415  10.810  13.1900
# Walking          18.0   1.858333  0.880055   1.22   1.385   1.485   1.7875
#
#                Climb (m)              ... Average Speed (km/h)             \
#            max     count        mean  ...                count       mean
# Type                                  ...
# Cycling  49.18      29.0  240.551724  ...                 29.0  19.125172
# Running  38.32     459.0  124.788671  ...                459.0  11.056296
# ...
